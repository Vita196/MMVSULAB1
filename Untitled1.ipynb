# %% [markdown]
# <a href="https://colab.research.google.com/github/Vita196/MMVSULAB1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа №3

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import odeint
url = 'https://raw.githubusercontent.com/Vita196/MMVSULAB1/main/Population.csv'
df = pd.read_csv(url)
print(df)
Years = np.array(df['Years'])
Population = np.array(df['Population'])
def dydt(Years,Population):
  k = 0.0044
  return k*Years

plt.plot(Years, Population)
plt.grid(True)
plt.title('Численность населения г. Краснодар', fontsize=13)
# Out:
#     Years  Population
# 0    1951      465000
# 1    1952      470000
# 2    1953      475000
# 3    1954      480000
# 4    1955      485000
# 5    1956      490000
# 6    1957      495000
# 7    1958      500000
# 8    1969      550000
# 9    1975      600000
# 10   1987      650000
# 11   1991      540000
# 12   1993      580000
# 13   1996      610000
# 14   1999      590000
# 15   2003      646200
# 16   2005      715400
# 17   2009      713133
# 18   2010      744995
# 19   2012      763899
# 20   2013      784048
# 21   2014      805680
# 22   2015      829677
# 23   2016      853848
# 24   2017      881476
# 25   2018      899541
# 26   2019      918145
# 27   2020      932629
# 28   2021      948827
# 29   2022      974319
# Text(0.5, 1.0, 'Численность населения г. Краснодар')
